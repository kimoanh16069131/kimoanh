# %% [markdown]
# <a href="https://colab.research.google.com/github/kimoanh16069131/kimoanh/blob/master/19_12_th%E1%BB%91ng_k%C3%AA_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/BrainSize.csv')

# %%
import pandas as pd

df1 = pd.read_csv('http://www.statslab.cam.ac.uk/~rds37/teaching/statistical_modelling/BrainSize.csv')

df2 = pd.read_excel('https://mathcs.org/statistics/course/00-data/distribution-data.xls')

# %%
#kích thước là 38 (số hàng) x 7 (số cột)
df.shape
# Out:
# (38, 7)

# %%
#khám phá số hàng hoặc cột bằng cách sử dụng lập chỉ mục
df.shape[0]
# Out:
# 38

# %%
#trước tiên sử dụng 0 để lấy số cột của khung dữ liệu và sau đó, tất nhiên, số hàng sử dụng 1.
df.shape[1]
# Out:
# 7

# %%
#để biết thêm thông tin về đối tượng DataFrame có thể sử dụng phương thức info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Gender     38 non-null     object
#  1   FSIQ       38 non-null     int64
#  2   VIQ        38 non-null     int64
#  3   PIQ        38 non-null     int64
#  4   Weight     38 non-null     int64
#  5   Height     38 non-null     float64
#  6   MRI_Count  38 non-null     int64
#  7   GenderCat  38 non-null     category
# dtypes: category(1), float64(1), int64(5), object(1)
# memory usage: 2.3+ KB

# %%
#mô tả thống kê - sử dụng hàm describe() trong pandas
df.describe()
# Out:
#              FSIQ         VIQ         PIQ      Weight     Height     MRI_Count
# count   38.000000   38.000000   38.000000   38.000000  38.000000  3.800000e+01
# mean   113.552632  112.131579  111.342105  151.052632  68.421053  9.067542e+05
# std     23.815391   22.939605   22.597867   23.478509   3.993790  7.256175e+04
# min     77.000000   71.000000   72.000000  106.000000  62.000000  7.906190e+05
# 25%     90.250000   90.250000   89.250000  135.250000  66.000000  8.548115e+05
# 50%    116.500000  113.000000  115.000000  146.500000  68.000000  9.053990e+05
# 75%    135.000000  129.000000  128.000000  172.000000  70.375000  9.495405e+05
# max    144.000000  150.000000  150.000000  192.000000  77.000000  1.079549e+06

# %%
#nếu bạn chỉ muốn dữ liệu mô tả cho các đối tượng (ví dụ: chuỗi),
#bạn có thể sử dụng mã này: df.describe (include = ['O']) 
df.describe(include=['O'])
# Out:
#         Gender
# count       38
# unique       2
# top     Female
# freq        20

# %%
##và nếu bạn chỉ muốn mô tả các biến phân loại, hãy sử dụng lệnh df.describe (include= ['category'])
#thay đổi kiểu dữ liệu, bạn có thể chạy mã sau
#add thêm cột GenderCat = cột Gender có kiểu dữ liệu là category
df['GenderCat'] = df['Gender'].astype('category')
df.describe(include=['category'])
# Out:
#        GenderCat
# count         38
# unique         2
# top       Female
# freq          20

# %%
df
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count GenderCat
# 0   Female   133  132  124     118    64.5     816932    Female
# 1     Male   139  123  150     143    73.3    1038437      Male
# 2     Male   133  129  128     172    68.8     965353      Male
# 3   Female   137  132  134     147    65.0     951545    Female
# 4   Female    99   90  110     146    69.0     928799    Female
# 5   Female   138  136  131     138    64.5     991305    Female
# 6   Female    92   90   98     175    66.0     854258    Female
# 7     Male    89   93   84     134    66.3     904858      Male
# 8     Male   133  114  147     172    68.8     955466      Male
# 9   Female   132  129  124     118    64.5     833868    Female
# 10    Male   141  150  128     151    70.0    1079549      Male
# 11    Male   135  129  124     155    69.0     924059      Male
# 12  Female   140  120  147     155    70.5     856472    Female
# 13  Female    96  100   90     146    66.0     878897    Female
# ...

# %%
df.describe(include='all')
# Out:
#         Gender        FSIQ         VIQ  ...     Height     MRI_Count  GenderCat
# count       38   38.000000   38.000000  ...  38.000000  3.800000e+01         38
# unique       2         NaN         NaN  ...        NaN           NaN          2
# top     Female         NaN         NaN  ...        NaN           NaN     Female
# freq        20         NaN         NaN  ...        NaN           NaN         20
# mean       NaN  113.552632  112.131579  ...  68.421053  9.067542e+05        NaN
# std        NaN   23.815391   22.939605  ...   3.993790  7.256175e+04        NaN
# min        NaN   77.000000   71.000000  ...  62.000000  7.906190e+05        NaN
# 25%        NaN   90.250000   90.250000  ...  66.000000  8.548115e+05        NaN
# 50%        NaN  116.500000  113.000000  ...  68.000000  9.053990e+05        NaN
# 75%        NaN  135.000000  129.000000  ...  70.375000  9.495405e+05        NaN
# max        NaN  144.000000  150.000000  ...  77.000000  1.079549e+06        NaN
#
# ...

# %%
#liệt kê tất cả các biến (cột) trong khung dữ liệu Pandas
df.columns
# Out:
# Index(['Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count',
#        'GenderCat'],
#       dtype='object')

# %%
#in 5 hàng đầu tiên của tập dữ liệu
df.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count GenderCat
# 0  Female   133  132  124     118    64.5     816932    Female
# 1    Male   139  123  150     143    73.3    1038437      Male
# 2    Male   133  129  128     172    68.8     965353      Male
# 3  Female   137  132  134     147    65.0     951545    Female
# 4  Female    99   90  110     146    69.0     928799    Female

# %%
#in 5 hàng cuối cùng của khung dữ liệu
df.tail()
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count GenderCat
# 33  Female   133  129  128     153    66.5     948066    Female
# 34    Male   140  150  124     144    70.5     949395      Male
# 35  Female    88   86   94     139    64.5     893983    Female
# 36    Male    81   90   74     148    74.0     930016      Male
# 37    Male    89   91   89     179    75.5     935863      Male

# %%
#Để nhận thống kê tóm tắt của một biến cụ thể (hoặc hai biến cụ thể), bạn có thể chọn (các) cột như sau:
df[['FSIQ']].describe()
# Out:
#              FSIQ
# count   38.000000
# mean   113.552632
# std     23.815391
# min     77.000000
# 25%     90.250000
# 50%    116.500000
# 75%    135.000000
# max    144.000000

# %%
#Để tính toán thống kê tương quan (tạo ma trận tương quan) của dữ liệu, bạn có thể sử dụng phương pháp corr ():
df.corr()
# Out:
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.945114  0.934427 -0.051483 -0.118448   0.333714
# VIQ        0.945114  1.000000  0.776020 -0.076088 -0.118976   0.300279
# PIQ        0.934427  0.776020  1.000000  0.002512 -0.093156   0.377782
# Weight    -0.051483 -0.076088  0.002512  1.000000  0.699614   0.513378
# Height    -0.118448 -0.118976 -0.093156  0.699614  1.000000   0.588377
# MRI_Count  0.333714  0.300279  0.377782  0.513378  0.588377   1.000000

# %%
df3 = pd.read_csv('http://www.statslab.cam.ac.uk/~rds37/teaching/statistical_modelling/Cycling.csv')

# %%
df3
# Out:
#              vehicle          colour  passing.distance  ... helmet  kerb       city
# 0       ordinary car            blue             2.114  ...     No  0.50  Salisbury
# 1                HGV             red             0.998  ...     No  0.50  Salisbury
# 2     LGV or minibus            blue             1.817  ...     No  0.50  Salisbury
# 3       ordinary car         unknown             1.640  ...     No  0.50  Salisbury
# 4                bus           other             1.544  ...     No  0.50  Salisbury
# ...              ...             ...               ...  ...    ...   ...        ...
# 2300    ordinary car  silver or grey             1.260  ...    Yes  1.25  Salisbury
# 2301    ordinary car             red             1.172  ...    Yes  1.25  Salisbury
# 2302             HGV           white             0.814  ...    Yes  1.25  Salisbury
# 2303    ordinary car            blue             0.900  ...    Yes  1.25  Salisbury
# ...

# %%
df3.hist(column='passing.distance')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa20c52a278>]],
#       dtype=object)
